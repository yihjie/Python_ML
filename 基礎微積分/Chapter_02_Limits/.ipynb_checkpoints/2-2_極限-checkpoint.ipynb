# %% [markdown]
# lim (1/n) = 0

# %%
import matplotlib.pyplot as plt

x = [x for x in range(1, 101)]
y = [1 / y for y in x]

plt.axis([0, 100, 0, 1])
plt.plot(x, y)
plt.xlabel("n")
plt.ylabel("y")
plt.grid()
plt.show()
